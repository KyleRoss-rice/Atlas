# %% [markdown]
# <a href="https://colab.research.google.com/github/KyleRoss-rice/Atlas/blob/master/tests/AtlasInference.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Atlas Inference
# _Based on colab by Atlas' authors: https://colab.research.google.com/drive/19_kJSkrQqPhQGIWpEpbZlk48b8p5ZRTO?usp=sharing_
#
# This colab runs inference on the Atlas model using user-provided data and weights. Default data and weights are used, if none are provided.
#
# The output is a reconstructed 3D mesh in ascii `ply` format.
#
# Changes:
# * Fixed bug related to `pyyaml` that prevented the script from working in the original colab
# * Added functionality to allow user to provide data and weights
# * Removed encoding of a video; output is now only the reconstructed mesh
#
# TODO:
# * Contact Atlas' authors to update their colab to fix `pyyaml` bug

# %%
# !pip install \
  pyyaml==5.1 \
  detectron2 -f https://dl.fbaipublicfiles.com/detectron2/wheels/cu101/torch1.6/index.html \
  open3d>=0.10.0.0 \
  trimesh>=3.7.6 \
  pyquaternion>=0.9.5 \
  pytorch-lightning>=0.8.5 \
  pyrender>=0.1.43 \

# !pip install --upgrade scikit-image>=0.17.2
# Out:
# ERROR: Operation cancelled by user

# %%
import os
from google.colab import files

# Clone the repo
# !git clone https://github.com/magicleap/Atlas.git
# %cd Atlas

# Download pretrained weights
if not os.path.exists('results'):
  # !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=12P29x6revvNWREdZ01ufJwMFPl-FEI_V' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=12P29x6revvNWREdZ01ufJwMFPl-FEI_V" -O results.zip && rm -rf /tmp/cookies.txt
  # !unzip results.zip

# Download sample data
if not os.path.exists('data'):
  # !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=13-D7QNVZjj864E768zJ7IWDDqY6agUES' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=13-D7QNVZjj864E768zJ7IWDDqY6agUES" -O data.zip && rm -rf /tmp/cookies.txt
  # !unzip data.zip

# verify everything was downloaded
# !ls
# !ls results/release/semseg
# !ls data/sample/sample1
# Out:
# Cloning into 'Atlas'...
# remote: Enumerating objects: 10, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 73 (delta 4), reused 1 (delta 0), pack-reused 63
# Unpacking objects: 100% (73/73), done.
# /content/Atlas
# --2020-11-23 22:00:59--  https://docs.google.com/uc?export=download&confirm=4dMW&id=12P29x6revvNWREdZ01ufJwMFPl-FEI_V
# Resolving docs.google.com (docs.google.com)... 172.217.15.110, 2607:f8b0:4004:809::200e
# Connecting to docs.google.com (docs.google.com)|172.217.15.110|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-10-cc-docs.googleusercontent.com/docs/securesc/inb3f7jl6hgv4n4su7h9pbts2pgclj7t/13r8fh7blu56vb4njs2hbjieq5lifnf2/1606168800000/06775661448174390731/11781983632756681074Z/12P29x6revvNWREdZ01ufJwMFPl-FEI_V?e=download [following]
# ...

# %%
# prepare data
# !python prepare_data.py --path data --path_meta data --dataset sample
# Out:
# preparing sample1
# preparing sample1 frame 0/250
# preparing sample1 frame 25/250
# preparing sample1 frame 50/250
# preparing sample1 frame 75/250
# preparing sample1 frame 100/250
# preparing sample1 frame 125/250
# preparing sample1 frame 150/250
# preparing sample1 frame 175/250
# preparing sample1 frame 200/250
# preparing sample1 frame 225/250

# %%
# run inference
# !python inference.py --model results/release/semseg/final.ckpt --scenes data/sample/sample1/info.json --voxel_dim 208 208 80
# Out:
# 0 1 sample sample1 0 250
# 0 1 sample sample1 25 250
# 0 1 sample sample1 50 250
# 0 1 sample sample1 75 250
# 0 1 sample sample1 100 250
# 0 1 sample sample1 125 250
# 0 1 sample sample1 150 250
# 0 1 sample sample1 175 250
# 0 1 sample sample1 200 250
# 0 1 sample sample1 225 250

# %%
# download reconstructed mesh
files.download('results/release/semseg/test_final/sample1.ply')
